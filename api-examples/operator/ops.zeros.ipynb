# %% [markdown]
# ## mindspore.ops.ones(size, dtype=None) -〉 Tensor
# 创建一个值全为0的Tensor。
# - 输入：
#     * size: tuple[int]]、list[int]、int或mindspore的tensor（数据类型为int32或int64）。
#     * dtype: mindspore.dtype。
# - 返回：mindspore的tensor。

# %% [markdown]
# 1、参数比较：
# | mindspore   | torch       | jax         |
# | :----:      | :----:      | :----:      |
# | size        | size        | shape       |
# | dtype       | out         | dtype       |
# |             | dtype       | device      |
# |             | layout      |       |
# |             | device      |          |
# |             | requires_grad   |        |
#
#
# * torch额外提供了out出参方式, layout用于设置内存存储结构，以及requires_grad设置自动求导是否记录操作。
# * torch和jax都提供了device参数，用于设置返回值提交到哪个设备上。
# * mindspore.ops.ones与mindspore.ops.zeros参数名不一致。

# %% [markdown]
# 2、返回值比较

# %%
import mindspore as ms
import torch
import jax.numpy as jnp

y1 = ms.ops.zeros((2,3))
y2 = torch.zeros((2,3))
y3 = jnp.zeros((2,3))
print ('mindspore output:\n',y1)
print('\n')
print ('torch output:\n',y2)
print('\n')
print ('jax output:\n',y3)
# Out:
# mindspore output:
#  [[0. 0. 0.]
#  [0. 0. 0.]]
#
#
# torch output:
#  tensor([[0., 0., 0.],
#         [0., 0., 0.]])
#
#
# jax output:
#  [[0. 0. 0.]
#  [0. 0. 0.]]

# %% [markdown]
# 指定数据类型：

# %%
y1 = ms.ops.zeros(4, dtype=ms.bool_)
y2 = torch.zeros(4, dtype=bool)
y3 = jnp.zeros(4, dtype=bool)
print ('mindspore output:\n',y1)
print('\n')
print ('torch output:\n',y2)
print('\n')
print ('jax output:\n',y3)
# Out:
# mindspore output:
#  [False False False False]
#
#
# torch output:
#  tensor([False, False, False, False])
#
#
# jax output:
#  [False False False False]

# %% [markdown]
# * ms与jax不返回类型。

# %% [markdown]
# 3、报错信息比较：

# %%
y1 = ms.ops.zeros(1.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 y1 = ms.ops.zeros(1.5)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/mindspore/ops/auto_generate/gen_ops_def.py:8275, in zeros(size, dtype)
#    8244 def zeros(size, dtype=None):
#    8245     r"""
#    8246     Creates a tensor filled with value zeros, whose shape and type are described by the first argument `size` and second argument `dtype` respectively.
#    8247
#    (...)
#    8273          [0. 0.]]
#    8274     """
# -> 8275     return zeros_op(size, dtype)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/mindspore/ops/operations/manually_defined/ops_def.py:1874, in Zeros.__call__(self, size, type)
#    1873 def __call__(self, size, type=None):
# -> 1874     return _convert_stub(pyboost_zeros(self, [size, type if type is None else \
#    1875         handler.dtype_to_type_id('Zeros', 'type', type)]))
#
# TypeError: Failed calling Zeros with "Zeros()(size=float, dtype=mindspore.dtype)".
# The valid calling should be:
# "Zeros()(size=<int, list of int, Tensor, tuple of int>, dtype=<mindspore.dtype>)".
#
# ----------------------------------------------------
# - C++ Call Stack: (For framework developers)
# ----------------------------------------------------
# mindspore/ccsrc/pipeline/pynative/pynative_utils.cc:1294 PrintTypeCastError

# %%
y2 = torch.zeros(1.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 y2 = torch.zeros(1.5)
#
# TypeError: zeros(): argument 'size' (position 1) must be tuple of ints, but found element of type float at pos 0

# %%
y3 = jnp.zeros(1.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 y3 = jnp.zeros(1.5)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py:3387, in zeros(shape, dtype, device)
#    3385 if (m := _check_forgot_shape_tuple("zeros", shape, dtype)): raise TypeError(m)
#    3386 dtypes.check_user_dtype_supported(dtype, "zeros")
# -> 3387 shape = canonicalize_shape(shape)
#    3388 return lax.full(shape, 0, _jnp_dtype(dtype), sharding=_normalize_to_sharding(device))
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py:98, in canonicalize_shape(shape, context)
#      95 def canonicalize_shape(shape: Any, context: str="") -> core.Shape:
#      96   if (not isinstance(shape, (tuple, list)) and
#      97       (getattr(shape, 'ndim', None) == 0 or ndim(shape) == 0)):
# ---> 98     return core.canonicalize_shape((shape,), context)
#      99   else:
#     100     return core.canonicalize_shape(shape, context)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/jax/_src/core.py:1689, in canonicalize_shape(shape, context)
#    1687 except TypeError:
#    1688   pass
# -> 1689 raise _invalid_shape_error(shape, context)
#
# TypeError: Shapes must be 1D sequences of concrete values of integer type, got (1.5,).

# %% [markdown]
# 当输入类型不正确时，报错信息torch简洁明确。建议ms优化。
