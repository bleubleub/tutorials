# %% [markdown]
# ## mindspore.ops.zeros_like(input, *, dtype=None) -〉 Tensor
# 返回值为0的Tensor，shape与输入相同。
# - 输入：
#     * input: mindspore的tensor
#     * dtype: mindspore.dtype
# - 返回：mindspore的tensor。

# %% [markdown]
# 1、参数比较：
# | mindspore   | torch       | jax         |
# | :----:      | :----:      | :----:      |
# | input       | input       | a           |
# | dtype       | dtype       | shape       |
# |             | layout      | dtype       |
# |             | device      | device      |
# |             | requires_grad   |        |
# |             | memory_format   |        |
#
#
# * torch额外提供了layout用于设置内存存储结构，requires_grad设置自动求导是否记录操作以及memory_format内存存储方式。
# * jax额外提供了shape参数用于覆盖input的shape。
# * torch和jax都提供了device参数，用于设置返回值提交到哪个设备上。

# %% [markdown]
# 2、返回值比较

# %%
import numpy as np
import mindspore as ms
import torch
import jax.numpy as jnp

input = np.array([0., -3., 7, -7])

y1 = ms.ops.zeros_like(ms.tensor(input))
y2 = torch.zeros_like(torch.tensor(input))
y3 = jnp.zeros_like(input)
print ('mindspore output:\n',y1)
print('\n')
print ('torch output:\n',y2)
print('\n')
print ('jax output:\n',y3)
# Out:
# mindspore output:
#  [0. 0. 0. 0.]
#
#
# torch output:
#  tensor([0., 0., 0., 0.], dtype=torch.float64)
#
#
# jax output:
#  [0. 0. 0. 0.]

# %% [markdown]
# 通过shape参数覆盖input的shape:

# %%
y3 = jnp.zeros_like(input, shape=(2,3))
print ('jax output:\n',y3)
# Out:
# jax output:
#  [[0. 0. 0.]
#  [0. 0. 0.]]

# %% [markdown]
# * ms与jax不返回类型。

# %% [markdown]
# 3、报错信息比较：

# %%
y1 = ms.ops.zeros_like(1.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 y1 = ms.ops.zeros_like(1.5)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/mindspore/ops/function/array_func.py:1095, in zeros_like(input, dtype)
#    1063 def zeros_like(input, *, dtype=None):
#    1064     r"""
#    1065     Creates a tensor filled with 0, with the same size as input, and the given dtype.
#    1066
#    (...)
#    1093          [0. 0.]]
#    1094     """
# -> 1095     _dtype = input.dtype if dtype is None else dtype
#    1096     output = zeros_like_(input)
#    1097     output = cast_(output, _dtype)
#
# AttributeError: 'float' object has no attribute 'dtype'

# %%
y2 = torch.zeros_like(1.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 y2 = torch.zeros_like(1.5)
#
# TypeError: zeros_like(): argument 'input' (position 1) must be Tensor, not float

# %%
input = [2, 4, 3, 1]
y3 = jnp.zeros_like(input)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 input = [2, 4, 3, 1]
# ----> 2 y3 = jnp.zeros_like(input)
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py:3304, in zeros_like(a, dtype, shape, device)
#    3298 @util.implements(np.zeros_like)
#    3299 def zeros_like(a: ArrayLike | DuckTypedArray,
#    3300                dtype: DTypeLike | None = None,
#    3301                shape: Any = None, *,
#    3302                device: xc.Device | Sharding | None = None) -> Array:
#    3303   if not (hasattr(a, 'dtype') and hasattr(a, 'shape')):  # support duck typing
# -> 3304     util.check_arraylike("zeros_like", a)
#    3305   dtypes.check_user_dtype_supported(dtype, "zeros_like")
#    3306   if shape is not None:
#
# File /opt/anaconda3/envs/mindspore/lib/python3.9/site-packages/jax/_src/numpy/util.py:335, in check_arraylike(fun_name, emit_warning, stacklevel, *args)
#     332   warnings.warn(msg + " In a future JAX release this will be an error.",
#     333                 category=DeprecationWarning, stacklevel=stacklevel)
#     334 else:
# --> 335   raise TypeError(msg.format(fun_name, type(arg), pos))
#
# TypeError: zeros_like requires ndarray or scalar arguments, got <class 'list'> at position 0.

# %% [markdown]
# 当输入类型不正确时，报错信息torch简洁明确。建议ms优化。
